# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab.ipynb")

# %% [markdown]
# # Lab 7 – Regular Expressions
#
# ## DSC 80, Fall 2023
#
# ### Due Date: Monday, November 20th at 11:59 PM

# %% [markdown]
# ## Instructions
# Welcome to the seventh lab assignment in DSC 80 this quarter!
#
# Much like in DSC 10, this Jupyter Notebook contains the statements of the problems and provides code and Markdown cells to display your answers to the problems. Unlike DSC 10, the notebook is *only* for displaying a readable version of your final answers. The coding will be done in an accompanying `lab.py` file that is imported into the current notebook, and **you will only submit that `lab.py` file**, not this notebook!
#
# Some additional guidelines:
# - **Unlike in DSC 10, labs will have both public tests and hidden tests.** The bulk of your grade will come from your scores on hidden tests, which you will only see on Gradescope after the assignment deadline.
# - **Do not change the function names in the `lab.py` file!** The functions in the `lab.py` file are how your assignment is graded, and they are graded by their name. If you changed something you weren't supposed to, you can find the original code in the [course GitHub repository](https://github.com/dsc-courses/dsc80-2023-fa).
# - Notebooks are nice for testing and experimenting with different implementations before designing your function in your `lab.py` file. You can write code here, but make sure that all of your real work is in the `lab.py` file, since that's all you're submitting.
# - **To ensure that all of your work to be submitted is in `lab.py`, we've provided an additional uneditable notebook, called `lab-validation.ipynb`, that contains only the tests and their setup. Make sure you are able to run it top-to-bottom without error before submitting!**
# - You are encouraged to write your own additional helper functions to solve the lab, as long as they also end up in `lab.py`.
#
# **Importing code from `lab.py`**:
#
# * Below, we import the `.py` file that's contained in the same directory as this notebook.
# * We use the `autoreload` notebook extension to make changes to our `lab.py` file immediately available in our notebook. Without this extension, we would need to restart the notebook kernel to see any changes to `lab.py` in the notebook.
#     - `autoreload` is necessary because, upon import, `lab.py` is compiled to bytecode (in the directory `__pycache__`). Subsequent imports of `lab` merely import the existing compiled python.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lab import *

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import re

# %% [markdown]
# ## Question 1 – Practice with Regular Expressions 🛠
# <div class="alert alert-block alert-warning">
# <b>Note</b>: The functions in this question all have doctests in their docstrings. The doctests constitute the public tests; we will still run hidden tests on each of your functions. <b>Please don't change any of the docstrings!</b>
# </div>
#
# Regular expressions can be tricky, and the best way to gain familiarity with them is through lots of practice. In this question, you will work through ten exercises, each of which requires you to write a regular expression that matches strings that satisfy certain criteria. Make sure to take a close look at the doctests for each function in `lab.py`, as they provide useful guidance for the types of strings you should and shouldn't match.
#
# ***Notes:***
# - Make sure to refer to the [Regular Expression Resources](https://dsc80.com/resources/#regular-expressions) posted on the course website. In particular, we recommend having [regex101.com](https://regex101.com/) open while working, along with the [cheat sheet](https://dsc80.com/resources/other/berkeley-regex-reference.pdf).
#
# - Each exercise has a star rating, between 1 (⭐️) and 3 (⭐️⭐️⭐️) stars, indicating its difficulty level (1 being the easiest, 3 being the hardest). If you are spending lots of time on 1-star exercises, take a close look at the syntax from lecture, as there is probably an easier way of writing the necessary pattern!
#
# <br>
#
# ### Exercise 1 (⭐️)
#
# Write a regular expression that matches strings that have `'['` as the third character and `']'` as the sixth character.
#
# <br>
#
# ### Exercise 2 (⭐️)
#
# Write a regular expression that matches strings that are phone numbers that start with `'(858)'` and follow the format `'(xxx) xxx-xxxx'` (`'x'` represents a digit).
#
# ***Note:*** There is a space between `'(xxx)'` and `'xxx-xxxx'`.
#
# <br>
#
# ### Exercise 3 (⭐️)
#
# Write a regular expression that matches strings that:
# - are between 6 and 10 characters long (inclusive),
# - contain only alphanumeric characters, whitespace and `'?'`, and
# - end with `'?'`.
#
# <br>
#
# ### Exercise 4 (⭐️⭐️)
#
# Write a regular expression that matches strings with exactly two `'$'`, one of which is at the start of the string, such that:
# - the characters between the two `'$'` can be anything (including nothing) except the lowercase letters `'a'`, `'b'`, and `'c'`, (and `'$'`), and
# - the characters after the second `'$'` can only be the **lowercase or uppercase** letters `'a'`/`'A'`, `'b'`/`'B'`, and `'c'`/`'C'`, with every `'a'`/`'A'` before every `'b'`/`'B'`, and every `'b'`/`'B'` before every `'c'`/`'C'`. There must be at least one `'a'` or `'A'`, at least one `'b'` or `'B'`, and at least one `'c'` or `'C'`.
#
#
# <br>
#
# ### Exercise 5 (⭐️)
# Write a regular expression that matches strings that represent valid Python file names, including the extension.
#
# ***Note:*** For simplicity, assume that file names only contain letters, numbers, and underscores (`'_'`).
#
# <br>
#
# ### Exercise 6 (⭐️)
# Write a regular expression that matches strings that:
# - are made up of only lowercase letters and exactly one underscore (`'_'`), and
# - have at least one lowercase letter on both sides of the underscore.
#
# <br>
#
# ### Exercise 7 (⭐️)
# Write a regular expression that matches strings that start with and end with an underscore (`'_'`).
#
# <br>
#
# ### Exercise 8 (⭐️)
#
# Apple serial numbers are strings of length 1 or more that are made up of any characters, other than
# - the uppercase letter `'O'`,
# - the lowercase letter `'i`', and
# - the number `'1'`.
#
# Write a regular expression that matches strings that are valid Apple serial numbers.
#
# <br>
#
# ### Exercise 9 (⭐️⭐️)
#
# ID numbers are formatted as `'SC-NN-CCC-NNNN'`, where
# - SC represents state code in uppercase (e.g. `'CA'`),
# - NN represents a number with 2 digits (e.g. `'98'`),
# - CCC represents a three letter city code in uppercase (e.g. `'SAN'`), and
# - NNNN represents a number with 4 digits (e.g. `'1024'`).
#
# Write a regular expression that matches strings that are ID numbers corresponding to the cities of `'SAN'` or `'LAX'`, or the state of `'NY'`. Assume that there is only one city named `'SAN'` and only one city named `'LAX'`.
#
# <br>
#
# ### Exercise 10 (⭐️⭐️⭐️)
#
# Write a function named `match_10` that takes in a string and:
# - converts the string to lowercase,
# - removes all non-alphanumeric characters (i.e. removes everything that is not in the `\w` character class), and the letter `'a'`, and
# - returns a list of every **non-overlapping** three-character substring in the remaining string, starting from the beginning of the string.
#
# For instance, consider the following doctest:
#
# ```py
# >>> match_10('Ab..DEF')
# ['bde']
# ```
#
# Here's how `match_10` should process `'Ab..DEF'`:
#
# 1. Convert to lowercase: `'ab..def'`.
# 2. Remove non-alphanumeric characters and the letter `'a'`: `'bdef'`.
# 3. Starting from the beginning of the string, there is only a single non-overlapping three character substring: `'bde'`. Hence, we return `['bde']`.
#
# ***Note:*** Perform your operations in the exact order described above, otherwise your code may not pass all the tests. Don't use a `for`-loop.

# %%
string = "ABCdef"
string = string.lower()
string = re.sub(r'[^\w]|a', '', string)
string[:3]
result = []
for i in range(0, len(string) - 2, 3):
    substring = string[i:i+3]
    if substring not in result:
      result.append(substring)
result
# Out:
# ['bcd']

# %%
match_1("ab[cd]ef")
# Out:
# True

# %%
match_2('(858) 456-7890b')
# Out:
# False

# %%
match_3('qwertsd?')
# Out:
# True

# %%
match_6('aab_cbb_bc')
# Out:
# False

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Question 2 – Capturing Groups in Regular Expressions 📡
#
# The dataset stored in `data/messy.txt` contains personal information from a fictional website that a user scraped from web server logs. Within this dataset, there are four fields that are of interest to you:
# 1. Email Addresses (assume they are alphanumeric usernames and domain names)
# 2. [Social Security Numbers](https://en.wikipedia.org/wiki/Social_Security_number#Structure)
# 3. Bitcoin Addresses (alphanumeric strings of long length)
# 4. Street Addresses
#
# Complete the implementation of the function `extract_personal`, which takes in a string containing the contents of a server log file (like `open('data/messy.txt').read()`) and returns a **tuple of four separate lists** containing values of the 4 pieces of information listed above (in the order listed above). Do **not** keep empty values.
#
# ***Note:*** Since this data is messy, your function will be allowed to miss ~5% of the records in each list. Good spot checking using certain useful substrings (e.g. `'@'` for emails) should help assure correctness! Your function will be tested on a sample of the file `messy.txt`.
#
# ***Hint:*** There are multiple "delimiters" in use in the file; there are few enough of them that you can safely determine what they are.

# %%
# experiment with extract_personal using the file s below
fp = Path('data') / 'messy.txt'
s = open(fp, encoding='utf8').read()

# %%
re.findall(r'\b\w+@\w+\.\w+\b', s)
re.findall(r'\b\d{3}-\d{2}-\d{4}\b', s)
re.findall(r'\bbitcoin:\w+\b', s)
re.findall(r'\d{1,6} [A-Za-z0-9 ]+', s)
# Out:
# ['814 Monterey Court',
#  '62 Hooker Park',
#  '27811 Clyde Gallagher Drive',
#  '32553 Riverside Pass',
#  '17157 Clemons Alley',
#  '75 Dorton Parkway',
#  '5 Manitowish Trail',
#  '84 Northland Center',
#  '64404 Sundown Street',
#  '47144 Mockingbird Street',
#  '413 Sutherland Court',
#  '8906 Almo Lane',
#  '34223 Graceland Crossing',
#  '94 Mcguire Lane',
#  '1 Delladonna Circle',
#  '169 Claremont Point',
#  '19475 Meadow Vale Crossing',
#  '147 Cascade Center',
#  '762 Knutson Terrace',
#  '301 Monument Trail',
#  '39 Buena Vista Alley',
#  '94 Barby Circle',
#  '98 Hansons Road',
#  '83525 Calypso Way',
#  '61 Heath Street',
#  '60 Bay Hill',
#  '923 Lindbergh Place',
#  '1 Elmside Circle',
#  '34 High Crossing Road',
#  '63 Bonner Lane',
#  '67 Superior Terrace',
#  '846 Acker Road',
#  '4 Menomonie Avenue',
#  '858 Arrowood Terrace',
#  '2566 Anhalt Trail',
#  '30840 Sherman Hill',
#  '29170 Parkside Lane',
#  '150 Logan Street',
#  '74 North Court',
#  '51374 8th Hill',
#  '6432 Continental Avenue',
#  '46916 Donald Court',
#  '1950 Beilfuss Hill',
#  '949 Park Meadow Park',
#  '38 Tennyson Junction',
#  '35 Melby Parkway',
#  '55 Eggendart Circle',
#  '36111 Drewry Pass',
#  '3 Messerschmidt Crossing',
#  '5 Hauk Terrace',
#  '4335 Calypso Parkway',
#  '3 Schurz Lane',
#  '11 Haas Drive',
#  '9639 Lindbergh Circle',
#  '4 Coleman Road',
#  '7751 Dahle Park',
#  '699 Northport Hill',
#  '754 Rockefeller Point',
#  '38375 Anhalt Street',
#  '4828 Carpenter Parkway',
#  '5 Golden Leaf Street',
#  '46594 Mallory Way',
#  '6108 Sundown Junction',
#  '92105 Melody Circle',
#  '8635 Dennis Way',
#  '7479 Rowland Terrace',
#  '75 Buena Vista Center',
#  '1 Michigan Junction',
#  '3543 Leroy Trail',
#  '47603 Doe Crossing Terrace',
#  '3 Monterey Alley',
#  '3 Cordelia Street',
#  '4890 Center Junction',
#  '12 Cardinal Road',
#  '84 Haas Court',
#  '46 Anthes Circle',
#  '074 Erie Pass',
#  '51827 Arkansas Crossing',
#  '83992 Schurz Way',
#  '3 Kenwood Way',
#  '721 Golf Course Crossing',
#  '2400 Farwell Way',
#  '0 Sheridan Hill',
#  '81427 Londonderry Alley',
#  '8083 Melby Lane',
#  '77851 Clyde Gallagher Road',
#  '274 Colorado Drive',
#  '4964 Johnson Drive',
#  '453 Mesta Drive',
#  '4 Cody Terrace',
#  '74711 Moulton Avenue',
#  '3410 Melrose Crossing',
#  '6253 Cascade Trail',
#  '289 South Place',
#  '744 Marcy Road',
#  '82060 Spenser Trail',
#  '652 Roxbury Plaza',
#  '57065 Dryden Trail',
#  '91304 Dottie Junction',
#  '10996 Schiller Alley',
#  '1 Almo Plaza',
#  '83 Starling Pass',
#  '8423 Green Crossing',
#  '3 Melody Lane',
#  '7341 Linden Alley',
#  '0 Columbus Hill',
#  '20 Shopko Road',
#  '77 Mayfield Way',
#  '785 Lighthouse Bay Point',
#  '6589 Forest Dale Way',
#  '5 Loomis Street',
#  '3 Randy Lane',
#  '9 Towne Hill',
#  '580 Lerdahl Street',
#  '77 5th Circle',
#  '3702 Ohio Center',
#  '860 Marquette Alley',
#  '11969 Fairview Lane',
#  '770 Shopko Place',
#  '997 Carpenter Plaza',
#  '081 Mayer Lane',
#  '5261 Maple Pass',
#  '7 Swallow Road',
#  '7612 Autumn Leaf Avenue',
#  '8 Bellgrove Junction',
#  '3 Helena Pass',
#  '06 Loftsgordon Alley',
#  '6402 Summer Ridge Court',
#  '88 Vera Drive',
#  '3162 Milwaukee Center',
#  '0 Northland Park',
#  '76307 Bashford Crossing',
#  '54 Doe Crossing Point',
#  '87 Pine View Way',
#  '5574 Pine View Crossing',
#  '17303 Ilene Circle',
#  '8 Warner Court',
#  '88400 New Castle Alley',
#  '6 Continental Terrace',
#  '7 Thompson Road',
#  '6 Harbort Terrace',
#  '11090 Almo Junction',
#  '21261 Norway Maple Drive',
#  '477 Carpenter Point',
#  '3360 Express Avenue',
#  '5908 Cardinal Hill',
#  '913 Gina Trail',
#  '8548 Boyd Junction',
#  '5250 Sommers Point',
#  '3 Green Ridge Parkway',
#  '78146 Kenwood Park',
#  '1376 Banding Plaza',
#  '2206 Lawn Alley',
#  '48279 Sullivan Avenue',
#  '1 Badeau Drive',
#  '55 Nelson Drive',
#  '096 Chinook Lane',
#  '82 Mayer Lane',
#  '3857 Northland Crossing',
#  '9 Dovetail Court',
#  '198 Oxford Circle',
#  '078 Mitchell Place',
#  '11 Thompson Place',
#  '8 Fair Oaks Place',
#  '893 Doe Crossing Center',
#  '96190 Sommers Pass',
#  '768 Bultman Center',
#  '288 Hintze Alley',
#  '61 Anthes Park',
#  '461 Ronald Regan Plaza',
#  '10072 Shoshone Terrace',
#  '711 Artisan Place',
#  '6 Commercial Pass',
#  '854 Coleman Place',
#  '09411 Ramsey Way',
#  '9633 Mifflin Lane',
#  '75 Briar Crest Center',
#  '24922 Gateway Pass',
#  '93 Garrison Center',
#  '189 Pearson Junction',
#  '39898 Doe Crossing Terrace',
#  '945 Forster Pass',
#  '647 Rieder Parkway',
#  '5 Parkside Terrace',
#  '1 Trailsway Place',
#  '2 Anthes Junction',
#  '3891 Bonner Pass',
#  '7915 Arapahoe Pass',
#  '9 Rusk Way',
#  '47278 Elgar Park',
#  '8788 Pierstorff Way',
#  '432 3rd Terrace',
#  '00081 Crowley Place',
#  '02 Lakewood Trail',
#  '3874 Blackbird Street',
#  '5328 Loomis Terrace',
#  '237 Mitchell Parkway',
#  '43526 Pepper Wood Place',
#  '8 Leroy Road',
#  '7 Troy Place',
#  '78676 Prairieview Road',
#  '6772 Ramsey Drive',
#  '43 Calypso Point',
#  '5504 Meadow Ridge Pass',
#  '058 Forster Plaza',
#  '992 Delladonna Crossing',
#  '0543 Maple Wood Drive',
#  '8608 Monument Junction',
#  '1345 Goodland Court',
#  '96 Garrison Drive',
#  '6 Florence Circle',
#  '503 Sugar Junction',
#  '50869 Westerfield Pass',
#  '2 Delladonna Avenue',
#  '94665 Corscot Pass',
#  '8485 Hanson Junction',
#  '582 Thierer Park',
#  '90 Fallview Center',
#  '19756 Petterle Drive',
#  '65 Artisan Hill',
#  '4636 Welch Crossing',
#  '25931 Vermont Road',
#  '325 Superior Alley',
#  '01 Armistice Circle',
#  '41 Morning Crossing',
#  '0218 Daystar Circle',
#  '57823 Harper Trail',
#  '732 Pearson Circle',
#  '93 Fuller Place',
#  '9797 Steensland Court',
#  '54 Rowland Road',
#  '9509 Dennis Alley',
#  '84 Northridge Park',
#  '378 Talmadge Terrace',
#  '33140 Southridge Center',
#  '31 La Follette Circle',
#  '2568 Warner Court',
#  '21 Pawling Street',
#  '774 Northland Junction',
#  '6303 Di Loreto Drive',
#  '9 Longview Plaza',
#  '461 Anderson Avenue',
#  '05 Lawn Park',
#  '070 Village Avenue',
#  '2 Hermina Court',
#  '873 Nova Circle',
#  '542 International Park',
#  '04 Michigan Street',
#  '0892 Maywood Point',
#  '7745 Susan Trail',
#  '9218 Burrows Court',
#  '72142 Gulseth Terrace',
#  '3832 Oxford Way',
#  '278 Forest Dale Court',
#  '91091 5th Center',
#  '89128 Fordem Hill',
#  '3797 Fuller Place',
#  '04115 Darwin Avenue',
#  '3264 Village Court',
#  '0445 Oneill Alley',
#  '95405 Becker Place',
#  '05 Columbus Lane',
#  '1 Hudson Parkway',
#  '5 Westport Lane',
#  '27 Prentice Place',
#  '12 South Pass',
#  '786 Ludington Plaza',
#  '06505 Lakeland Road',
#  '99 Shelley Court',
#  '13179 Dottie Point',
#  '058 Thierer Terrace',
#  '7 Roxbury Pass',
#  '192 Holy Cross Plaza',
#  '829 Northfield Terrace',
#  '96305 Butterfield Drive',
#  '4308 Kropf Trail',
#  '10549 Kipling Park',
#  '290 Stuart Street',
#  '93016 Meadow Ridge Plaza',
#  '8955 Harper Crossing',
#  '480 Barby Place',
#  '571 Rowland Street',
#  '805 Harper Terrace',
#  '3 Nevada Hill',
#  '7 Nova Road',
#  '7 Macpherson Circle',
#  '97541 Kropf Court',
#  '13 Commercial Parkway',
#  '4494 Golf Course Terrace',
#  '93860 Eagan Avenue',
#  '2 Eastlawn Lane',
#  '1931 Fallview Way',
#  '3 Waywood Way',
#  '58196 Green Alley',
#  '7958 Elka Circle',
#  '02487 Carberry Trail',
#  '95025 Moose Drive',
#  '4599 Meadow Ridge Circle',
#  '6592 8th Point',
#  '47 Northwestern Hill',
#  '4648 Vahlen Trail',
#  '5 Transport Road',
#  '16544 Fremont Alley',
#  '98 Briar Crest Alley',
#  '8 Melody Way',
#  '8752 Oxford Street',
#  '84 Ridge Oak Plaza',
#  '63 Spenser Center',
#  '9 Tennyson Road',
#  '3 Sauthoff Road',
#  '21 Maple Wood Place',
#  '7526 Aberg Park',
#  '367 Prentice Park',
#  '0 Badeau Drive',
#  '948 Northview Hill',
#  '752 Vermont Place',
#  '99628 Glacier Hill Road',
#  '33 Londonderry Lane',
#  '6767 Boyd Alley',
#  '860 Northfield Lane',
#  '0552 Ludington Lane',
#  '96 Lawn Plaza',
#  '3 Corben Center',
#  '1 Algoma Avenue',
#  '8924 Porter Parkway',
#  '67 Springs Plaza',
#  '892 Sugar Avenue',
#  '590 Park Meadow Way',
#  '7440 Grayhawk Park',
#  '67 Loftsgordon Street',
#  '9863 Shopko Point',
#  '1 Upham Junction',
#  '3566 Nobel Avenue',
#  '9 Mosinee Center',
#  '45 Muir Trail',
#  '347 Roth Junction',
#  '9 Sauthoff Circle',
#  '49708 Myrtle Center',
#  '40 Hintze Place',
#  '29756 Cottonwood Lane',
#  '53 Derek Point',
#  '51 Crowley Hill',
#  '7 Cardinal Place',
#  '91 Chive Circle',
#  '225 Fieldstone Park',
#  '6 Helena Junction',
#  '69690 Kennedy Circle',
#  '2 Lukken Center',
#  '335 Mallard Way',
#  '499 Prairie Rose Alley',
#  '350 Nevada Circle',
#  '9392 Fremont Place',
#  '858 Tennyson Way',
#  '082 Katie Circle',
#  '852 Evergreen Street',
#  '422 Jackson Street',
#  '93 Dunning Center',
#  '13563 Kinsman Plaza',
#  '12 Blackbird Alley',
#  '89 Lakeland Place',
#  '588 Bellgrove Road',
#  '6 Fuller Park',
#  '92611 Scoville Terrace',
#  '8 Dunning Court',
#  '296 Eliot Center',
#  '1 Loftsgordon Drive',
#  '790 Express Drive',
#  '81730 Sauthoff Road',
#  '5 Lunder Avenue',
#  '9 Warrior Hill',
#  '06 Fairfield Parkway',
#  '644 Parkside Lane',
#  '25214 Meadow Vale Court',
#  '98 Cambridge Terrace',
#  '81644 Blaine Point',
#  '1442 Moulton Circle',
#  '5 Crest Line Crossing',
#  '369 Warner Center',
#  '4753 Farwell Trail',
#  '594 Southridge Center',
#  '6509 Lakewood Gardens Place',
#  '235 Lien Court',
#  '581 Clove Hill',
#  '3 Canary Pass',
#  '93685 Kedzie Terrace',
#  '0057 Coolidge Place',
#  '2923 Spohn Terrace',
#  '33 Melody Center',
#  '805 Amoth Junction',
#  '9 Sloan Point',
#  '82094 Del Mar Place',
#  '4925 Redwing Trail',
#  '743 Nancy Way',
#  '918 Lunder Court',
#  '2 Duke Avenue',
#  '0 Holy Cross Point',
#  '23795 Hermina Crossing',
#  '56 Boyd Parkway',
#  '96 Atwood Junction',
#  '94 Village Green Parkway',
#  '3 Mallard Circle',
#  '322 Texas Drive',
#  '0831 Burrows Drive',
#  '63686 Northfield Alley',
#  '03 North Place',
#  '923 Merry Terrace',
#  '6073 Harbort Junction',
#  '100 Londonderry Avenue',
#  '5369 Fairview Alley',
#  '942 Oxford Court',
#  '7 Mariners Cove Alley',
#  '06935 Alpine Drive',
#  '68282 High Crossing Way',
#  '91661 Hanover Lane',
#  '8 Ridgeway Road',
#  '397 Sage Junction',
#  '66 Green Avenue',
#  '8969 Norway Maple Crossing',
#  '558 Dwight Trail',
#  '274 Cardinal Terrace',
#  '12197 Anhalt Street',
#  '3161 Cardinal Circle',
#  '58139 Butternut Road',
#  '8265 Jackson Avenue',
#  '322 Memorial Circle',
#  '1 Fieldstone Center',
#  '16485 Troy Plaza',
#  '60 Sunfield Terrace',
#  '02175 Old Gate Trail',
#  '0871 Barnett Way',
#  '0243 Arrowood Junction',
#  '3 Summerview Street',
#  '8758 Dorton Trail',
#  '6 Lakewood Gardens Place',
#  '7381 Summit Center',
#  '13146 Crowley Court',
#  '98842 Continental Terrace',
#  '67 Lyons Terrace',
#  '5300 Victoria Terrace',
#  '25 Anzinger Way',
#  '938 Eliot Center',
#  '956 Pond Junction',
#  '21736 Doe Crossing Center',
#  '05 Carberry Center',
#  '9866 Memorial Plaza',
#  '5219 Vidon Crossing',
#  '53 Lyons Parkway',
#  '2 Everett Drive',
#  '50391 Nancy Junction',
#  '57147 Armistice Plaza',
#  '5734 Kipling Terrace',
#  '3199 Golden Leaf Hill',
#  '686 Red Cloud Point',
#  '889 Mitchell Park',
#  '92 Monica Lane',
#  '1200 Shoshone Center',
#  '50551 Muir Park',
#  '1 Crownhardt Lane',
#  '01256 Sachs Junction',
#  '2620 Scofield Hill',
#  '3809 Briar Crest Hill',
#  '950 Mosinee Way',
#  '959 Dawn Junction',
#  '858 Mesta Alley',
#  '6 Wayridge Junction',
#  '5 Coolidge Alley',
#  '330 Anhalt Trail',
#  '1782 Donald Street',
#  '668 2nd Circle',
#  '21631 Fisk Terrace',
#  '5 Melody Hill',
#  '9 Brickson Park Center',
#  '8 Aberg Terrace',
#  '83676 Nobel Junction',
#  '1766 Crownhardt Junction',
#  '8 Gina Crossing',
#  '14 Anderson Crossing',
#  '16 Blue Bill Park Park',
#  '67453 Kipling Center',
#  '9 8th Hill',
#  '5 Melrose Terrace',
#  '9462 Pleasure Plaza',
#  '50277 Browning Park',
#  '889 David Alley',
#  '46 Lunder Crossing',
#  '8582 Judy Crossing',
#  '528 Westend Drive',
#  '4 Spohn Court',
#  '67143 Briar Crest Court',
#  '6972 Buell Center',
#  '1243 Sunbrook Street',
#  '6 Memorial Lane',
#  '0 Butternut Alley',
#  '626 Vidon Crossing',
#  '8711 Dexter Drive',
#  '218 Maple Wood Drive',
#  '1 Fieldstone Center',
#  '31792 Spaight Crossing',
#  '270 Pepper Wood Pass',
#  '77 Arapahoe Hill',
#  '5560 West Park',
#  '142 Lakewood Gardens Trail',
#  '86318 Memorial Trail',
#  '5042 Mallory Crossing',
#  '8892 Thompson Lane',
#  '6 Manufacturers Pass',
#  '1 Killdeer Park',
#  '87254 Fulton Road',
#  '1834 Eastwood Lane',
#  '82436 1st Way',
#  '7 Ridge Oak Avenue',
#  '6 Rutledge Plaza',
#  '7663 8th Road',
#  '897 Moulton Lane',
#  '399 Village Green Parkway',
#  '24404 6th Drive',
#  '126 Glacier Hill Road',
#  '057 Mockingbird Road',
#  '24 Coolidge Pass',
#  '8647 Surrey Way',
#  '8 Daystar Way',
#  '30 Sunbrook Parkway',
#  '099 Roxbury Park',
#  '28 Center Circle',
#  '457 Dawn Hill',
#  '52009 Doe Crossing Drive',
#  '66 Ridgeview Junction',
#  '94 Barnett Plaza',
#  '26911 Service Road',
#  '0 Di Loreto Trail',
#  '242 Elmside Terrace',
#  '71219 Portage Terrace',
#  '276 1st Point',
#  '28 Golden Leaf Drive',
#  '91614 Washington Center',
#  '34 Becker Road',
#  '5981 Farragut Way',
#  '8 Pleasure Street',
#  '9600 Elmside Place',
#  '7132 Oak Valley Road',
#  '68 Acker Place',
#  '570 Ohio Pass',
#  '1 Brown Avenue',
#  '344 Heffernan Way',
#  '9 Maple Junction',
#  '46 Gina Way',
#  '70 Golden Leaf Trail',
#  '26 Mosinee Circle',
#  '02618 Blaine Park',
#  '9 Londonderry Pass',
#  '2 Havey Way',
#  '74 Hudson Terrace',
#  '92 Marquette Avenue',
#  '6 Golden Leaf Terrace',
#  '20979 Transport Drive',
#  '6 Bartillon Junction',
#  '3 Dakota Road',
#  '58658 David Circle',
#  '8 Thackeray Lane',
#  '6063 Mccormick Way',
#  '25 Sugar Point',
#  '4 Meadow Valley Plaza',
#  '13937 Westend Alley',
#  '30373 Parkside Center',
#  '75364 Fordem Way',
#  '0 Pepper Wood Terrace',
#  '34217 Mosinee Crossing',
#  '54 Butternut Hill',
#  '9301 3rd Drive',
#  '325 Nancy Pass',
#  '0 Moose Way',
#  '311 Stuart Plaza',
#  '80182 Fairfield Park',
#  '247 Montana Parkway',
#  '23298 Sauthoff Plaza',
#  '2412 Maryland Road',
#  '22859 Crescent Oaks Park',
#  '287 Eagan Terrace',
#  '0 Nelson Crossing',
#  '006 Burrows Pass',
#  '7 Cordelia Junction',
#  '60 Clove Center',
#  '238 Vera Court',
#  '0915 Almo Crossing',
#  '82 Shopko Parkway',
#  '58 Manley Junction',
#  '841 Katie Place',
#  '4305 Mandrake Pass',
#  '6120 Columbus Circle',
#  '79320 Nevada Place',
#  '4 Briar Crest Plaza',
#  '70270 Lunder Alley',
#  '4 Green Avenue',
#  '85229 Pawling Point',
#  '762 Fisk Parkway',
#  '8 Browning Terrace',
#  '821 Buhler Place',
#  '52964 Kedzie Avenue',
#  '97 Basil Trail',
#  '35 Raven Avenue',
#  '8179 Arkansas Court',
#  '21365 Crest Line Trail',
#  '19 Hovde Court',
#  '7796 Derek Place',
#  '6107 Spohn Crossing',
#  '5 Carpenter Alley',
#  '2 Northport Pass',
#  '7 Esker Point',
#  '36 Northview Point',
#  '01669 Harbort Crossing',
#  '7 Starling Avenue',
#  '2 Maywood Parkway',
#  '76877 Donald Way',
#  '3 Rusk Trail',
#  '5 Stang Road',
#  '763 Anzinger Center',
#  '27 Ruskin Hill',
#  '7818 Hintze Road',
#  '6953 Mesta Street',
#  '44 Park Meadow Trail',
#  '7200 3rd Hill',
#  '0003 Riverside Court',
#  '914 8th Alley',
#  '7 Duke Lane',
#  '71142 Mccormick Place',
#  '016 Bluejay Pass',
#  '2 Morningstar Crossing',
#  '9 Briar Crest Alley',
#  '96135 Dahle Plaza',
#  '1725 Mallory Plaza',
#  '93732 Waubesa Street',
#  '629 Meadow Ridge Avenue',
#  '23101 Anthes Point',
#  '8342 Jenifer Alley',
#  '0049 Clemons Circle',
#  '499 Scofield Court',
#  '32 Bultman Point',
#  '843 Buhler Circle',
#  '9842 Dapin Drive',
#  '160 Declaration Center',
#  '7 Southridge Trail',
#  '5223 Sunfield Avenue',
#  '01 Mosinee Trail',
#  '51747 Schlimgen Hill',
#  '7540 Fallview Lane',
#  '78013 Holmberg Plaza',
#  '126 Menomonie Center',
#  '8700 Portage Circle',
#  '6 Homewood Crossing',
#  '251 Sunnyside Parkway',
#  '9 Northridge Crossing',
#  '11 Moland Road',
#  '45 Darwin Hill',
#  '9 Magdeline Avenue',
#  '41 Novick Pass',
#  '32138 Myrtle Plaza',
#  '76 Golf Way',
#  '1172 Pierstorff Court',
#  '60321 Londonderry Parkway',
#  '6 Maryland Park',
#  '5 Spenser Plaza',
#  '5908 Chinook Place',
#  '65551 Westend Avenue',
#  '364 Beilfuss Crossing',
#  '3992 Memorial Way',
#  '7 Briar Crest Parkway',
#  '934 Farragut Road',
#  '71374 Manufacturers Point',
#  '568 Sauthoff Trail',
#  '81063 Dorton Junction',
#  '43313 Sutherland Court',
#  '4318 Susan Place',
#  '7678 Marcy Crossing',
#  '3 Larry Avenue',
#  '07 Riverside Crossing',
#  '29 Talmadge Terrace',
#  '40 Rusk Park',
#  '1 Village Terrace',
#  '57856 Mariners Cove Trail',
#  '548 Pearson Pass',
#  '4 Sherman Court',
#  '547 Crownhardt Crossing',
#  '87222 Basil Alley',
#  '43 Ruskin Court',
#  '04 Paget Parkway',
#  '11 Utah Trail',
#  '203 Columbus Alley',
#  '38946 Del Sol Park',
#  '0 Valley Edge Park',
#  '6 Thompson Way',
#  '628 Colorado Point',
#  '2737 Eastwood Avenue',
#  '9 Morning Park',
#  '98 Glendale Trail',
#  '47 Clarendon Court',
#  '94 Westridge Terrace',
#  '51425 Del Mar Point',
#  '242 Hayes Pass',
#  '6973 Saint Paul Point',
#  '0022 Spohn Junction',
#  '7 Farwell Pass',
#  '7948 Canary Junction',
#  '1 Clove Alley',
#  '78274 Ohio Lane',
#  '067 Stone Corner Trail',
#  '23 Steensland Way',
#  '9 Gulseth Circle',
#  '40918 Sheridan Center',
#  '45 Waywood Point',
#  '2 Onsgard Parkway',
#  '2334 Annamark Center',
#  '5669 Myrtle Alley',
#  '52768 Union Plaza',
#  '32378 Shopko Lane',
#  '8 Bunting Point',
#  '9508 Hazelcrest Point',
#  '91326 Roth Pass',
#  '33 Linden Court',
#  '37 American Ash Way',
#  '5 Mayer Pass',
#  '2 Springs Road',
#  '4318 Service Circle',
#  '31905 Weeping Birch Court',
#  '640 Sage Way',
#  '5 Green Way',
#  '181 Warner Place',
#  '1 Loomis Park',
#  '2073 Summerview Way',
#  '7019 Vermont Park',
#  '281 Raven Way',
#  '52014 Crownhardt Lane',
#  '50 Sachs Terrace',
#  '33 Carey Crossing',
#  '27 Loeprich Point',
#  '60387 Ryan Pass',
#  '05486 Bluejay Drive',
#  '4 Messerschmidt Point',
#  '2 Carpenter Crossing',
#  '884 Monument Road',
#  '6 Warbler Place',
#  '6 Utah Hill',
#  '776 Ridgeview Avenue',
#  '22 Burrows Terrace',
#  '38363 Jenna Street',
#  '73925 Menomonie Plaza',
#  '0 South Alley',
#  '872 Burrows Crossing',
#  '22375 Clove Plaza',
#  '8 Hauk Crossing',
#  '1 Morningstar Crossing',
#  '6156 Laurel Way',
#  '413 Merchant Pass',
#  '83 North Way',
#  '0 Chinook Way',
#  '940 Fisk Drive',
#  '487 Bartelt Park',
#  '48314 Homewood Alley',
#  '5012 Comanche Road',
#  '73046 Oriole Lane',
#  '5 Pleasure Terrace',
#  '53642 Del Mar Alley',
#  '7499 Fairfield Junction',
#  '72 Northland Drive',
#  '962 Spohn Terrace',
#  '0620 Esker Road',
#  '12055 Village Alley',
#  '40875 West Avenue',
#  '2 4th Alley',
#  '4 Delladonna Center',
#  '93173 West Point',
#  '8783 Parkside Junction',
#  '7706 Memorial Court',
#  '86590 Manufacturers Road',
#  '818 Delaware Avenue',
#  '66 Schurz Circle',
#  '210 Manufacturers Junction',
#  '2 Leroy Court',
#  '97528 Thompson Terrace',
#  '432 Barnett Street',
#  '4 Sundown Crossing',
#  '1 Algoma Crossing',
#  '564 Toban Pass',
#  '950 Fulton Hill',
#  '0271 Menomonie Avenue',
#  '195 Luster Avenue',
#  '85 Moland Point',
#  '88987 Paget Parkway',
#  '4340 Elgar Park',
#  '832 Kings Place',
#  '7 Jay Point',
#  '96 Northridge Trail',
#  '82 Buena Vista Pass',
#  '6 Brickson Park Center',
#  '41392 Nancy Avenue',
#  '0267 Harbort Crossing',
#  '69 Dennis Circle',
#  '261 Westport Junction',
#  '1155 Vermont Center',
#  '732 Butterfield Plaza',
#  '161 Fuller Street',
#  '03 Blue Bill Park Hill',
#  '12 Lillian Center',
#  '14361 Packers Terrace',
#  '9 Burrows Drive',
#  '24256 Stang Circle',
#  '7 Erie Junction',
#  '532 Bay Plaza',
#  '3128 Pepper Wood Point',
#  '3328 Novick Plaza',
#  '6837 Knutson Hill',
#  '675 Manley Street',
#  '86389 Monica Center',
#  '74694 Farragut Circle',
#  '90 Anhalt Road',
#  '89701 Kennedy Court',
#  '34770 Mendota Lane',
#  '5316 Old Gate Drive',
#  '49608 Dryden Court',
#  '95116 Westerfield Alley',
#  '0 Lawn Road',
#  '131 Southridge Circle',
#  '7 Kropf Plaza',
#  '77 Amoth Crossing',
#  '458 Cascade Street',
#  '2 Miller Crossing',
#  '88 Vidon Road',
#  '808 Ramsey Terrace',
#  '96 Kedzie Street',
#  '06 Algoma Terrace',
#  '260 Fair Oaks Alley',
#  '93 Dayton Place',
#  '55296 Gateway Avenue',
#  '1 Larry Plaza',
#  '6 Chinook Way',
#  '019 Burrows Way',
#  '4 Larry Street',
#  '04653 Porter Alley',
#  '6 Esch Lane',
#  '1 Portage Place',
#  '4 Crescent Oaks Alley',
#  '20616 Canary Pass',
#  '71349 Carpenter Street',
#  '139 Fremont Street',
#  '0303 Buhler Drive',
#  '7 Swallow Circle',
#  '141 David Parkway',
#  '74 Fremont Pass',
#  '3620 Bartillon Parkway',
#  '7932 Melvin Center',
#  '49 Grasskamp Terrace',
#  '2768 Waubesa Court',
#  '50991 Doe Crossing Circle',
#  '383 Autumn Leaf Alley',
#  '42860 Clove Parkway',
#  '587 Gateway Avenue',
#  '43603 Nobel Place',
#  '35383 Surrey Center',
#  '58410 Mesta Lane',
#  '214 Hollow Ridge Parkway',
#  '276 Hagan Hill',
#  '374 Superior Pass',
#  '0945 Mitchell Center',
#  '35379 Forster Lane',
#  '0425 Melrose Avenue',
#  '6297 Barby Avenue',
#  '2216 Harbort Point',
#  '87988 Wayridge Circle',
#  '0 Mccormick Center',
#  '471 Almo Lane',
#  '028 Drewry Street',
#  '06190 Scott Plaza',
#  '67767 Merry Center',
#  '86 Bunting Pass',
#  '312 Portage Point',
#  '2901 Haas Drive',
#  '52282 Orin Way',
#  '958 Butternut Point',
#  '778 South Center',
#  '6 Hoepker Crossing',
#  '152 Prairieview Center',
#  '1839 Morningstar Court',
#  '7 Cambridge Crossing',
#  '947 Mallard Place',
#  '104 Hoffman Park',
#  '4244 Heffernan Circle',
#  '72 Harbort Road',
#  '3675 Swallow Park',
#  '89384 Graceland Street',
#  '01 La Follette Plaza',
#  '240 Del Sol Park',
#  '13 Stephen Park',
#  '854 Pine View Plaza',
#  '58 Hooker Park',
#  '7 East Terrace',
#  '86 Bobwhite Street',
#  '0 Artisan Place',
#  '825 Mayfield Circle',
#  '424 Mallory Way',
#  '8524 Huxley Trail',
#  '33 Algoma Junction',
#  '48 Summer Ridge Crossing',
#  '976 Arkansas Junction',
#  '66697 Kings Road',
#  '0230 Weeping Birch Lane',
#  '15 Hoard Road',
#  '95608 Crest Line Court',
#  '05 Artisan Court',
#  '83 Hovde Drive',
#  '46130 Becker Street',
#  '0 Veith Drive',
#  '8389 Brown Plaza',
#  '91007 Mosinee Park',
#  '81 Sommers Street',
#  '47 Luster Circle',
#  '9 Ruskin Avenue',
#  '04 Westport Lane',
#  '4 Rowland Point',
#  '96 Judy Terrace',
#  '94 Stuart Center',
#  '7769 Portage Lane',
#  '1088 Redwing Place',
#  '107 Sycamore Lane',
#  '45254 Hoepker Center',
#  '50255 Sommers Point',
#  '30658 5th Point',
#  '6304 Browning Point',
#  '90 Hansons Circle',
#  '95 Coleman Circle',
#  '89302 Del Mar Alley',
#  '4 Anthes Terrace',
#  '15643 Charing Cross Crossing',
#  '5262 Duke Plaza',
#  '94739 Pennsylvania Drive',
#  '23 Coolidge Crossing',
#  '320 Mayer Terrace',
#  '541 Anthes Way',
#  '6851 Messerschmidt Plaza',
#  '43490 Grover Way',
#  '21 Granby Lane',
#  '16 Pierstorff Way',
#  '10 Homewood Road',
#  '99 Pearson Pass',
#  '886 Thackeray Road',
#  '459 Bowman Crossing',
#  '09943 Daystar Crossing',
#  '9555 Bultman Park',
#  '429 Holy Cross Point',
#  '4 Charing Cross Pass',
#  '38154 Hoepker Terrace',
#  '30454 Clove Drive',
#  '273 Waywood Hill',
#  '50952 Evergreen Street',
#  '0 Cordelia Pass',
#  '6607 Sachs Way',
#  '58 Shasta Terrace',
#  '58 Redwing Center',
#  '3979 Old Gate Trail',
#  '04232 Monterey Circle']

# %%
# don't change this cell, but do run it -- it is needed for the tests
test_fp = Path('data') / 'messy.txt'
test_s = open(test_fp, encoding='utf8').read()
emails, ssn, bitcoin, addresses = extract_personal(test_s)

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ## Question 3 – TF-IDF 📊
#
# The dataset `data/reviews.txt` contains [Amazon reviews](https://cseweb.ucsd.edu/~jmcauley/datasets.html#amazon_reviews/) for ~200k phones and phone accessories. The dataset has already been "cleaned" for you. In this question, you will complete the implementation of a function, which takes in the reviews dataset as a Series (with one entry per review) as well as a single review, and returns the word that "best summarizes the single review" using TF-IDF.
#
# To do so, implement the two functions below.
#
# #### `tfidf_data`
# You will first need to decompose the review into individual words, count their frequencies, and calculate the TF-IDF score for each word. Complete the implementation of the function `tfidf_data`, which takes in the reviews data as a Series (`reviews_ser`) and a single review (`review`) from that Series and returns a DataFrame indexed by the words in `review` with four columns:
# - `'cnt'`: the number of times each word is found in the review (telling how frequently a word is used in the `review`)
# - `'tf'`: the term frequency for each word (giving an idea of how important each word relative to the other words in the `review`)
# - `'idf'`: the inverse document frequency for each word (helping understand how important each word is to the whole `reviews_ser`)
# - `'tfidf'` the TF-IDF for each word (measuring how important each word is to `review`, taking into account both the frequency of the word in the `review` and across `reviews_ser`)
#
# You may use a `for`-loop. The words in the outputted DataFrame may appear in any order.
#
# ***Hint:*** You may need to use the [`'\b'` character](https://www.regular-expressions.info/wordboundaries.html) somewhere.
#
# <br>
#
# #### `relevant_word`
#
# Complete the implementation of the function `tfidf_data`, which takes in the DataFrame that `tfidf_data` returns and returns the word that "best summarizes" the review. If there are multiple "best" summary words, return any one of them.

# %%
# experiment with tfidf_data using reviews_ser and review below 
fp = Path('data') / 'reviews.txt'
reviews_ser = pd.read_csv(fp, header=None).squeeze("columns")
review = open(Path('data') / 'reviews.txt', encoding='utf8').read().strip()

# %%
reviews_ser
# Out:
# 0        works great  i called t mobile and had this si...
# 1        these items looked to be of good quality and h...
# 2        this product arrive faster than i expected  i ...
# 3        i brought this for my sister who has a g2 but ...
# 4         i am both delighted and disappointed with del...
#                                ...
# 58297    bought i for my husband's phone a week ago  ni...
# 58298    the spring loaded adjustable holder looks nift...
# 58299    received on time  everything working less spea...
# 58300    i bought this battery pack with the mindset of...
# 58301              that work    but thats not the original
# Name: 0, Length: 58302, dtype: object

# %%
len(reviews_ser[0].strip().split())
# Out:
# 27

# %%
cnt = pd.Series(reviews_ser[0].strip().split()).value_counts()
tf = cnt/ len(reviews_ser[0].strip().split())
idf = np.log(len(reviews_ser) / reviews_ser.str.contains('works').sum())

# %%
reviews_ser[0].count(r'\bt\b')
cnt
# Out:
# a            2
# works        1
# great        1
# to           1
# speak        1
# can          1
# you          1
# or           1
# system       1
# automated    1
# have         1
# they         1
# minutes      1
# 5            1
# in           1
# activated    1
# card         1
# sim          1
# this         1
# had          1
# and          1
# mobile       1
# t            1
# called       1
# i            1
# rep          1
# dtype: int64

# %%
reviews_ser.str.split().str.len()
# Out:
# 0          27
# 1          25
# 2          28
# 3          53
# 4        1787
#          ...
# 58297      22
# 58298     230
# 58299      35
# 58300     468
# 58301       7
# Name: 0, Length: 58302, dtype: int64

# %%
def calculate_tf(review):
    words = review.strip().split()
    word_series = pd.Series(words)
    tf = word_series.value_counts() / len(words)
    return tf

# %%
tfidf_dict = {}
tf = calculate_tf(reviews_ser[0])
for word in tf.index:
    cnt = pd.Series(reviews_ser[0].strip().split()).value_counts()
    re_pat = fr'\b{word}\b'
    tf = len(re.findall(re_pat, reviews_ser[0].strip())) / len(reviews_ser[0].strip().split())
    idf = np.log(len(reviews_ser) / reviews_ser.str.contains(re_pat, regex=True).sum())
    tfidf_dict[word] = {'tf': tf, 'idf': idf, 'tfidf': tf * idf}

tfidf = pd.DataFrame.from_dict(tfidf_dict, orient='index')
tfidf['cnt'] = cnt

# %%
tfidf
# Out:
#                  tf       idf     tfidf  cnt
# a          0.074074  0.360392  0.026696    2
# works      0.037037  1.898413  0.070312    1
# great      0.037037  1.301647  0.048209    1
# to         0.037037  0.382649  0.014172    1
# speak      0.037037  5.505332  0.203901    1
# can        0.037037  1.456449  0.053943    1
# you        0.037037  1.096145  0.040598    1
# or         0.037037  1.523326  0.056419    1
# system     0.037037  4.633032  0.171594    1
# automated  0.037037  8.083020  0.299371    1
# have       0.037037  0.975412  0.036126    1
# they       0.037037  1.719130  0.063671    1
# minutes    0.037037  4.058661  0.150321    1
# 5          0.037037  2.271546  0.084131    1
# in         0.037037  0.844683  0.031285    1
# activated  0.037037  6.129205  0.227008    1
# card       0.037037  3.866786  0.143214    1
# sim        0.037037  4.989455  0.184795    1
# this       0.037037  0.441295  0.016344    1
# had        0.037037  1.689987  0.062592    1
# and        0.037037  0.248188  0.009192    1
# mobile     0.037037  4.076697  0.150989    1
# t          0.037037  1.063525  0.039390    1
# called     0.037037  4.923658  0.182358    1
# i          0.037037  0.254672  0.009432    1
# rep        0.037037  7.022148  0.260080    1

# %%
# don't change this cell, but do run it -- it is needed for the tests
fp = os.path.join('data', 'reviews.txt')
reviews_ser = pd.read_csv(fp, header=None).squeeze("columns")
review = open(os.path.join('data', 'review.txt'), encoding='utf8').read().strip()
q3_tfidf = tfidf_data(reviews_ser, review)

try:
    q3_rel = relevant_word(q3_tfidf)
except:
    q3_rel = None

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# ## Questions 4 and 5 – Tweet Analysis 🐥
#
# The dataset `data/ira.csv` contains tweets tagged by Twitter as likely being posted by the [Internet Research Agency](https://en.wikipedia.org/wiki/Internet_Research_Agency), the tweet factory facing allegations for attempting to influence US political elections.
#
# Questions 4 and 5 will focus on the following:
# - Question 4: Look at the hashtags present in the text and trends in their makeup.
# - Question 5: Prepare the dataset for modeling by creating features out of the text fields.

# %% [markdown]
# ### Question 4 – Hashtags #️⃣
#
# You may assume that a hashtag is any string without whitespace that immediately follows a `'#'`.
#
# #### `hashtag_list`
#
# Complete the implementation of the function `hashtag_list`, which takes in a Series of tweet texts and returns a Series containing a list of hashtags present in each tweet's text. If a tweet's text doesn't contain a hashtag, the Series should contain an empty list for that tweet. Don't include the `'#'` symbol in the lists that are returned.
#
# <br>
#
# #### `most_common_hashtag`
#
# Complete the implementation of the function `most_common_hashtag`, which takes in a Series of hashtag lists (as is outputted by `hashtag_list`) and returns a Series consisting of a single hashtag per tweet:
# - If the tweet's text has no hashtags, the entry should in the output Series should be `NaN`.
# - If the tweet's text has one distinct hashtag, the entry in the output Series should be that hashtag.
# - If the tweet's text has more than one hashtag, the entry in the output Series should be the most common hashtag **in the tweet's text** with respect to **the whole input Series**. If there is a tie for the most common, any of the most common can be returned.
#     - For example, if the input Series was `pd.Series([[2], [2], [3, 2, 3]])`, the output would be `pd.Series([2, 2, 2])`. Even though `3` was more common in the third list than `2`, `2` is more common than `3` among all hashtags in the Series.

# %%
# The public tests don't test your work on the `ira` data,
# but the hidden tests do.
# So, make sure to thoroughly test your work yourself!
fp = os.path.join('data', 'ira.csv')
ira = pd.read_csv(fp, names=['id', 'name', 'date', 'text'])

# %%
ira['text']
def extract_hashtags(tweet):
    return re.findall(r'#(\S+)', tweet)

re.findall(r'#(\S+)', ira['text'][4])
# Out:
# ['IHatePokemonGoBecause', 'PokesAreJokes.']

# %%
ira['text']
# Out:
# 0        The Best Exercise To Lose Belly Fat In 2 weeks...
# 1        RT @Philanthropy: Dozens of ‘hate groups’ have...
# 2        Artificial intelligence can find, map poverty,...
# 3        Uber balks at rules proposed by world’s busies...
# 4        RT @dirtroaddiva1: #IHatePokemonGoBecause he  ...
#                                ...
# 89995    Trump: Kasich shouldn't be allowed to run http...
# 89996    RT @JefLeeson: #ThingsYouCantIgnore The last s...
# 89997    RT @nealcarter: When someone said the first li...
# 89998    RT @indigenous01: #rantfortoday I speak the Wo...
# 89999    10 Things to Know for Monday https://t.co/XoOg...
# Name: text, Length: 90000, dtype: object

# %%
hashtag_list(ira['text'])
# Out:
# 0        [Exercise, LoseBellyFat, CatTV, TeenWolf]
# 1                                               []
# 2                                           [tech]
# 3                                           [news]
# 4           [IHatePokemonGoBecause, PokesAreJokes]
#                            ...
# 89995                                   [politics]
# 89996                        [ThingsYouCantIgnore]
# 89997                                           []
# 89998                               [rantfortoday]
# 89999                                       [news]
# Name: text, Length: 90000, dtype: object

# %%
text1 = hashtag_list(ira['text'])
most_common_hashtag(text1)
# Out:
# ['Exercise', 'LoseBellyFat', 'CatTV', 'TeenWolf', 'tech', 'news', 'IHatePokemonGoBecause', 'PokesAreJokes', 'health', 'IWouldPreferToForget', 'NowPlaying', 'rap', 'hiphop', 'music', 'AthleticsTVShows', 'HillaryRottenClinton', 'TrumpTapes', 'entertainment', 'sports', 'politics', 'StopIslam', 'IslamKills', 'ParisAttacks', 'SlowJamTV', 'assaultatspringvalleyhigh', 'Brussels', 'WakeUpAmerica', 'OscarsSoWhite', 'oscarssoboring', 'OscarHasNoColor', 'SanJose', 'SextingWentWrongWhen', '2016In4Words', 'BlackHistoryMonth', 'MakeMeHateYouInOnePhrase', 'politics', 'AlternativeAcronymInterpretations', 'Castros', 'AgencySpy', 'racism', 'BTP', 'world', 'news', 'ObamasWishList', 'MustBeBanned', 'RunDakRun', 'DallasCowboys', 'business', 'politics', 'aid', 'disaster', 'environment', 'NowPlaying', 'HipHop', 'HillaryClinton', 'imwithher', 'StLouis', 'IfICouldntLie', 'news', 'morningjoe', 'news', 'MalcolmShabazz', 'LoveOfMyLife', 'AddAMovieRuinAMovie', 'NationalSelfieDay', 'baseball', 'WeAreTheMedia', 'politics', 'HillaryForPrison', 'HillaryForPrision', 'SupremeSacrificeDay', 'sports', 'politics', 'ItsOfficiallySummerWhen', 'IHate____Because', 'ThingsNeverSaidInStarWars', 'IWouldPreferToForget', 'ElectionDay', 'streetharassment', 'AfricanArchitecture', 'Pyramids', 'IAmTechnically', 'IAmTechnically', 'NoOffenceBut', 'BlackSkinIsNotACrime', 'MansionElanTONIGHT', 'Baghdad', 'Iraq', 'MyBedroomIn3Words', 'world', 'news', 'GrowingUpWithObama', 'IfIHadABodyDouble', 'WorstPainEverIn3Words', 'world', 'news', 'ItsUnacceptableTo', 'local', 'SanDiego', 'IGetALittleWeirdAbout', 'sports', 'world', 'news', 'DontForgetToPack', 'coffee', 'ThingsThatShouldBeCensored', 'sports', 'SanFrancisco', 'BasketOfDeplorables', 'SurvivalGuideToThanksgiving', 'tech', 'crookedhillary', 'TrumpForPresident', 'BadNewYearsToasts', 'ToSaveMoneyI', 'PartyWentWrongWhen', 'health', 'Beyonce', 'CMAawards50', 'ItsUnacceptableTo', 'ToFeelBetterI', 'RuinADinnerInOnePhrase', 'news', 'SurvivalGuideToThanksgiving', 'LukeCage', 'BlackHeroesMatter', 'news', 'PartyWentWrongWhen', 'politics', 'SoG', 'BLM', 'ButIWasTweetingInstead', '2016In4Words', 'рубрикамоизавтраки', 'sports', 'MarthaAndSnoop', 'WorldPoetryDay', 'vss', 'Trump2016', 'StopIslam', 'IslamKills', 'debate', 'FakeTaxFacts', 'GrowingUpWithObama', 'BlackLivesMatter', 'SignsYouAreAmerican', 'DontTellAnyoneBut', 'IHatePokemonGoBecause', 'mustbebanned', 'Brexit', 'BeingBlackIs', 'TimeTravelerProblems', 'Foke', 'local', 'news', 'soundcloud', 'WorstPainEverIn3Words', 'AddAMovieRuinAMovie', 'feminists', 'FeminismIsAwful', 'IslamKills', 'Brussels', 'IReallyLikeYouBut', 'world', 'news', 'MentalIllnessIcebreakers', 'MillennialBillOfRights', 'ThingsYouCantIgnore', 'PureBlack', 'Hanukkah', 'SongMakesMeTearUp', 'HappyBirthdayJensenAckles', 'jensenackles', 'C', 'TheReligionOfOphthalmology', 'staywoke', 'blacklivesmatter', 'ThingsThatShouldBeCensored', 'imnotwithher', 'news', 'ThingsThatShouldBeCensored', 'ICelebrateTrumpWith', 'SanJose', 'SanJose', 'Vote', 'TopNews', 'news', 'sports', 'IGetDepressedWhen', 'FlintWaterCrisis', 'MAGA', 'tcot', 'TwoFaced', 'SellOut', 'Blacks', 'BadMonsterMovies', 'AMJoy', 'NotMyPresident', 'WrongThingsToSayAtAWedding', 'health', 'MomGoals', 'news', 'relationships', 'psychology', 'politics', 'Cubs', 'LHHRmusic', 'MyBestFriendIsntAllowed', 'RejectedDebateTopics', 'news', 'FBI', 'ClintonFoundation', 'ImpeachComey', 'SickHillary', '2016In4Words', 'health', 'Wisconsin', 'local', 'HowToSpotASocialist', 'Federated400', 'nascar', 'madampresident', 'HillaryForPrison2016', 'TrumpForPresident', 'world', 'news', 'health', 'BeingBlackIs', 'FollowTheMoney', 'GrowingUpWithObama', 'health', 'Facebook', 'spreadlove', 'endraci', 'ObamaNextJob', 'Hamilton', 'MikePence', 'AcceptableTortureMethod', 'rape', 'IsiahBritt', 'TyranBell', 'HowIGotBanned', 'HowToMakeAManGay', 'MakeTVSexy', 'IDontNeedACostumeBecause', 'ICelebrateTrumpWith', 'Swedish', 'StanfordUniversity', 'business', 'SecondHandGifts', 'art', 'InCaseAnyoneAsks', 'politics', 'NotMyS ...
# 0                       news
# 1                        NaN
# 2                       tech
# 3                       news
# 4                       news
#                 ...
# 89995               politics
# 89996    ThingsYouCantIgnore
# 89997                    NaN
# 89998           rantfortoday
# 89999                   news
# Length: 90000, dtype: object

# %%
grader.check("q4")
# Out:
# q4 results: All test cases passed!

# %% [markdown]
# ### Question 5 – Features 📋
#
# Now, create a DataFrame of features from the `ira` data.  That is, create a function `create_features` that takes in a DataFrame `ira` that has just a single column, `'text'`, and returns a DataFrame with the same index as `ira` (i.e. the rows correspond to the same tweets) and the following columns:
# * `'num_hashtags'`, the number of hashtags present in the tweet.
# * `'mc_hashtags'`, the most common hashtag associated to the tweet (using the result of `most_common_hashtag` from Question 4).
# * `'num_tags'`, the number of tags the tweet has (look for the presence of `'@'`).
# * `'num_links'`, the number of hyperlinks present in the tweet.
#     - A hyperlink is a string starting with `'http://'` or `'https://'`, not followed by whitespaces.
# * `'is_retweet'`, a Boolean describing whether the tweet is a retweet. A retweet is a tweet that **begins** with `'RT'`.
# * `'text'`, a version of the tweet's text that is cleaned according to the following steps, **in this exact order**:
#     1. All meta-information above (retweet info, tags, hyperlinks, and hashtags) should be replaced with a single space.
#     2. Everything other than letters, numbers, and spaces should be replaced with a single space.
#     3. All letters should be lowercase.
#     4. All words should be separated by exactly one space, and leading/trailing whitespace should be removed (stripped).
#
# The columns in the outputted DataFrame must be in the order `['text', 'num_hashtags', 'mc_hashtags', 'num_tags', 'num_links', 'is_retweet']`. (Remember, the DataFrame that `create_features` is called on only has a single column, `'text'`.)
#
# ***Notes:***
# - It's a good idea to make helper function for each column.
# - The `\w` character class in regex **does not** refer to letters, numbers, and spaces (or even just letters and numbers). As such, you can't use it here!
# - `create_features` will take a while to run on the entire dataset – test it on a small sample first!

# %%
# The doctests/public tests don't test your work on the `ira` data,
# but the hidden tests do.
# So, make sure to thoroughly test your work yourself!
fp = os.path.join('data', 'ira.csv')
ira = pd.read_csv(fp, names=['id', 'name', 'date', 'text'])

# %%
content = ira[['text']]
def num_hashtags(content):
    return len(re.findall(r'#[A-Za-z0-9]+', content))

# content['text'].apply(num_hashtags)
# ira['text'].apply(lambda x: most_common_hashtag(extract_hashtags(x))[0] if extract_hashtags(x) else None)
ira['text'].str.count('@[A-Za-z]+')
ira['text'].str.count('(http://\S+)|(https://\S+)')
ira['text'].str.startswith('RT') != 0
text = re.sub(r'@[A-Za-z]+|http[s]?://\S+|#[A-Za-z]+|RT', ' ', ira['text'][0])
text = re.sub(r'[^[A-Za-z0-9 ]+\s]', ' ', text)
text = text.lower()
text = re.sub(r'\s+', ' ', text)
text.strip()
# Out:
# 'the best exercise to lose belly fat in 2 weeks …'

# %%
# don't change this cell, but do run it -- it is needed for the tests
# (yes, we know it says "hidden" – there are still truly hidden tests in this question)
fp_hidden = 'data/ira_test.csv'
ira_hidden = pd.read_csv(fp_hidden, header=None)
text_hidden = ira_hidden.iloc[:, -1:]
text_hidden.columns = ['text']

test_hidden = create_features(text_hidden)

# %%
grader.check("q5")
# Out:
# q5 results: All test cases passed!

# %% [markdown]
# ## Congratulations! You're done with Lab 7! 🏁
#
# As a reminder, all of the work you want to submit needs to be in `lab.py`.
#
# To verify that all of your work is indeed in `lab.py`, and that you didn't accidentally implement a function in this notebook and not in `lab.py`, we've included another notebook in the lab folder, called `lab-validation.ipynb`. `lab-validation.ipynb` is a version of this notebook with only the `grader.check` cells and the code needed to set up the tests.
#
# ### **Go to `lab-validation.ipynb`, and go to Kernel > Restart & Run All.** This will check if all `grader.check` test cases pass using just the code in `lab.py`.
#
# Once you're able to pass all test cases in `lab-validation.ipynb`, including the call to `grader.check_all()` at the very bottom, then you're ready to submit your `lab.py` (and only your `lab.py`) to Gradescope. Once submitting to Gradescope, make sure to stick around until all test cases pass.
#
# There is also a call to `grader.check_all()` below in _this_ notebook, but make sure to also follow the steps above.

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1 results: All test cases passed!
#
# q2 results: All test cases passed!
#
# q3 results: All test cases passed!
#
# q4 results: All test cases passed!
#
# q5 results: All test cases passed!
